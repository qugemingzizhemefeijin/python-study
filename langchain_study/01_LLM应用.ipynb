# %%
import os

from langchain_community.llms import tongyi

key = os.getenv('TONGYI_API_KEY')
llm = tongyi.Tongyi(api_key=key)

# 调用模型使用
llm.invoke("夏天适合吃什么水果？回复几个水果名称就可以来！")
# Out:
# '西瓜、荔枝、桃子、芒果、葡萄'
